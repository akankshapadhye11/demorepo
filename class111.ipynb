# %% [markdown]
# # welcome to python

# %% [markdown]
# learning python

# %%
5**3
# Out:
# 125

# %%
a=10

# %%
a
# Out:
# 10

# %%
b=4

# %%
b
# Out:
# 4

# %%
pi=3.14
r=20

area=pi*r**2
area
# Out:
# 1256.0

# %%
circumference=2*pi*r
circumference
# Out:
# 125.60000000000001

# %%
name=input("enter name of the person")
# Out:
# enter name of the personjack

# %%
name
# Out:
# 'jack'

# %% [markdown]
# hello

# %%
x=int(input("enter length"))
# Out:
# enter length20

# %%
y=int(input("enter breadth"))
# Out:
# enter breadth50

# %%
x+y
# Out:
# 70

# %%
print("area of rectangle=",x+y)
# Out:
# area of rectangle= 70

# %% [markdown]
# bye bye python

# %%
country="norways"

# %%
country
# Out:
# 'norways'

# %%
len("norways")
# Out:
# 7

# %%
len(country)
# Out:
# 6

# %%
print("hello")
# Out:
# hello
